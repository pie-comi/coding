# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(-2, 5, 1000)
y=x**2

plt.plot(x, y)
plt.title("felicità del copa all'ora di pranzo")
plt.xlabel("felicità")
plt.ylabe("comi")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 10
#       8 plt.title("felicità del copa all'ora di pranzo")
#       9 plt.xlabel("felicità")
# ---> 10 plt.ylabe("comi")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylabe'
